# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
hate_crime = pd.read_csv('hate_crime.csv')
hate_crime
# Out:
#         INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 0              3015       1991  AR0040200          Rogers             NaN
# 1              3016       1991  AR0290100            Hope             NaN
# 2                43       1991  AR0350100      Pine Bluff             NaN
# 3                44       1991  AR0350100      Pine Bluff             NaN
# 4              3017       1991  AR0350100      Pine Bluff             NaN
# ...             ...        ...        ...             ...             ...
# 219572      1318026       2020  WY0170100        Sheridan             NaN
# 219573      1142103       2020  WY0210100        Evanston             NaN
# 219574      1318018       2020  WY0210100        Evanston             NaN
# 219575      1318022       2020  WY0210100        Evanston             NaN
# 219576      1318023       2020  WY0210100        Evanston             NaN
#
#        AGENCY_TYPE_NAME STATE_ABBR STATE_NAME       DIVISION_NAME REGION_NAME  \
# 0                  City         AR   Arkansas  West South Central       South
# 1                  City         AR   Arkansas  West South Central       South
# 2                  City         AR   Arkansas  West South Central       South
# 3                  City         AR   Arkansas  West South Central       South
# 4                  City         AR   Arkansas  West South Central       South
# ...                 ...        ...        ...                 ...         ...
# 219572             City         WY    Wyoming            Mountain        West
# 219573             City         WY    Wyoming            Mountain        West
# 219574             City         WY    Wyoming            Mountain        West
# 219575             City         WY    Wyoming            Mountain        West
# 219576             City         WY    Wyoming            Mountain        West
#
#         ...              OFFENDER_RACE      OFFENDER_ETHNICITY VICTIM_COUNT  \
# 0       ...                      White                     NaN            1
# 1       ...  Black or African American                     NaN            1
# 2       ...  Black or African American                     NaN            1
# 3       ...  Black or African American                     NaN            2
# 4       ...  Black or African American                     NaN            1
# ...     ...                        ...                     ...          ...
# 219572  ...                      White  Not Hispanic or Latino            2
# 219573  ...                    Unknown                 Unknown            1
# 219574  ...  Black or African American  Not Hispanic or Latino            1
# 219575  ...                      White  Not Hispanic or Latino            1
# 219576  ...                      White  Not Hispanic or Latino            1
#
#                                              OFFENSE_NAME  \
# 0                                            Intimidation
# 1                                          Simple Assault
# 2                                      Aggravated Assault
# 3       Aggravated Assault;Destruction/Damage/Vandalis...
# 4                                      Aggravated Assault
# ...                                                   ...
# 219572                                       Intimidation
# 219573           Destruction/Damage/Vandalism of Property
# 219574                                 Aggravated Assault
# 219575                                     Simple Assault
# 219576                                Theft From Building
#
#         TOTAL_INDIVIDUAL_VICTIMS                       LOCATION_NAME  \
# 0                            1.0  Highway/Road/Alley/Street/Sidewalk
# 1                            1.0  Highway/Road/Alley/Street/Sidewalk
# 2                            1.0                      Residence/Home
# 3                            1.0  Highway/Road/Alley/Street/Sidewalk
# 4                            1.0                 Service/Gas Station
# ...                          ...                                 ...
# 219572                       2.0                     Park/Playground
# 219573                       0.0                     Park/Playground
# 219574                       1.0                      Residence/Home
# 219575                       1.0                      Residence/Home
# 219576                       1.0                      Residence/Home
#
#                                                 BIAS_DESC  VICTIM_TYPES  \
# 0                          Anti-Black or African American    Individual
# 1                                              Anti-White    Individual
# 2                          Anti-Black or African American    Individual
# 3                                              Anti-White    Individual
# 4                                              Anti-White    Individual
# ...                                                   ...           ...
# 219572  Anti-Lesbian, Gay, Bisexual, or Transgender (M...    Individual
# 219573                                         Anti-White    Government
# 219574                                         Anti-White    Individual
# 219575                                        Anti-Female    Individual
# 219576                         Anti-Gender Non-Conforming    Individual
#
#        MULTIPLE_OFFENSE MULTIPLE_BIAS
# 0                     S             S
# 1                     S             S
# 2                     S             S
# 3                     M             S
# 4                     S             S
# ...                 ...           ...
# 219572                S             S
# 219573                S             S
# 219574                S             S
# 219575                S             S
# 219576                S             S
#
# [219577 rows x 28 columns]

# %%
hate_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219577 entries, 0 to 219576
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   INCIDENT_ID               219577 non-null  int64
#  1   DATA_YEAR                 219577 non-null  int64
#  2   ORI                       219577 non-null  object
#  3   PUB_AGENCY_NAME           219577 non-null  object
#  4   PUB_AGENCY_UNIT           6431 non-null    object
#  5   AGENCY_TYPE_NAME          219577 non-null  object
#  6   STATE_ABBR                219577 non-null  object
#  7   STATE_NAME                219577 non-null  object
#  8   DIVISION_NAME             219577 non-null  object
#  9   REGION_NAME               219577 non-null  object
#  10  POPULATION_GROUP_CODE     219577 non-null  object
#  11  POPULATION_GROUP_DESC     219577 non-null  object
#  12  INCIDENT_DATE             219577 non-null  object
#  13  ADULT_VICTIM_COUNT        51411 non-null   float64
#  14  JUVENILE_VICTIM_COUNT     49539 non-null   float64
#  15  TOTAL_OFFENDER_COUNT      219577 non-null  int64
#  16  ADULT_OFFENDER_COUNT      47130 non-null   float64
#  17  JUVENILE_OFFENDER_COUNT   47123 non-null   float64
#  18  OFFENDER_RACE             219557 non-null  object
#  19  OFFENDER_ETHNICITY        34873 non-null   object
#  20  VICTIM_COUNT              219577 non-null  int64
#  21  OFFENSE_NAME              219577 non-null  object
#  22  TOTAL_INDIVIDUAL_VICTIMS  216098 non-null  float64
#  23  LOCATION_NAME             219577 non-null  object
#  24  BIAS_DESC                 219577 non-null  object
#  25  VICTIM_TYPES              219577 non-null  object
#  26  MULTIPLE_OFFENSE          219577 non-null  object
#  27  MULTIPLE_BIAS             219577 non-null  object
# dtypes: float64(5), int64(4), object(19)
# memory usage: 46.9+ MB

# %%
# political climate csv
political = pd.read_csv('political_climate.csv')
political
# Out:
#     Congress  Year Start  Year End House Majority            Senate Majority  \
# 0        102        1991      1993      Democrats                  Democrats
# 1        103        1993      1995      Democrats                  Democrats
# 2        104        1995      1997    Republicans                Republicans
# 3        105        1997      1999    Republicans                Republicans
# 4        106        1999      2001    Republicans                Republicans
# 5        107        2001      2003    Republicans  Republicans / Democrats12
# 6        108        2003      2005    Republicans                Republicans
# 7        109        2005      2007    Republicans                Republicans
# 8        110        2007      2009      Democrats                Democrats13
# 9        111        2009      2011      Democrats                  Democrats
# 10       112        2011      2013    Republicans                  Democrats
# 11       113        2013      2015    Republicans                  Democrats
# 12       114        2015      2017    Republicans                Republicans
# 13       115        2017      2019    Republicans                Republicans
# 14       116        2019      2021      Democrats                Republicans
#
#     Presidency   President    Party Government
# 0   Republican  G.H.W Bush            Divided
# 1     Democrat     Clinton            Unified
# 2     Democrat     Clinton            Divided
# 3     Democrat     Clinton            Divided
# 4     Democrat     Clinton            Divided
# 5   Republican   G.W. Bush  Unified / Divided
# 6   Republican   G.W. Bush            Unified
# 7   Republican   G.W. Bush            Unified
# 8   Republican   G.W. Bush            Divided
# 9     Democrat       Obama            Unified
# 10    Democrat       Obama            Divided
# 11    Democrat       Obama            Divided
# 12    Democrat       Obama            Divided
# 13  Republican       Trump            Unified
# 14  Republican       Trump             Divided
